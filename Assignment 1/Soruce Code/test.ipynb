# %%
import os, sys, math
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("notebook", font_scale=1.4)
import epitopepredict as ep
# %matplotlib inline

# %%
# Reading datasets
cath = pd.read_csv('/Users/aneruthmohanasundaram/Documents/GitHub/Amino-Acid-Prediction/Assignment 1/Datasets/cath_info.txt',delimiter = "\t",header=None, names=["PDB_CODE", "CHAIN_CODE", "Prediction"])

dssp = pd.read_csv('/Users/aneruthmohanasundaram/Documents/GitHub/Amino-Acid-Prediction/Assignment 1/Datasets/dssp_info.txt', delimiter = "\t",header=None, names=["PDB_CODE", "CHAIN_CODE", "SEQ_POS","AMMINO_ACID","Prediction"])

stride = pd.read_csv('/Users/aneruthmohanasundaram/Documents/GitHub/Amino-Acid-Prediction/Assignment 1/Datasets/stride_info.txt',delimiter = "\t",header=None, names=["PDB_CODE", "CHAIN_CODE", "SEQ_POS","AMMINO_ACID","Prediction"])

# %%
cath['CHAIN_CODE'].unique()
# Out:
# array(['A', 'N', 'B', 'D', 'X', 'L', 'C', 'M', 'I', 'P', 'S'],
#       dtype=object)

# %%
stride.head()
# Out:
#   PDB_CODE CHAIN_CODE  SEQ_POS AMMINO_ACID Prediction
# 0     1w0n          A       12         ILE      Other
# 1     1w0n          A       13         THR       Beta
# 2     1w0n          A       14         LYS       Beta
# 3     1w0n          A       15         VAL       Beta
# 4     1w0n          A       16         GLU       Beta

# %%
stride['Prediction'].unique()
# Out:
# array(['Other', 'Beta', 'Helix'], dtype=object)

# %%
df_stride = stride[['PDB_CODE','CHAIN_CODE','SEQ_POS','AMMINO_ACID']][(stride['SEQ_POS']<40)]
df_stride.drop_duplicates(subset='PDB_CODE',inplace=True)
df_stride.head()
# Out:
#     PDB_CODE CHAIN_CODE  SEQ_POS AMMINO_ACID
# 0       1w0n          A       12         ILE
# 120     2gpi          A        0         GLY
# 209     1vbw          A        1         SER
# 277     2odk          A        2         HIS
# 327     2zxy          A        1         ALA

# %%
df_dssp = dssp[['PDB_CODE','CHAIN_CODE','SEQ_POS','AMMINO_ACID']][(dssp['SEQ_POS']<40)]
df_dssp.drop_duplicates(subset='PDB_CODE',inplace=True)
df_dssp.head()
# Out:
#     PDB_CODE CHAIN_CODE  SEQ_POS AMMINO_ACID
# 0       1w0n          A       12         ILE
# 120     2gpi          A        0         GLY
# 211     1vbw          A        1         SER
# 279     2odk          A        1           X
# 330     2zxy          A        1         ALA

# %%
def clear_asterisks(df, seqs_column_name, pct=30):
    indices = []
    for i, seq in enumerate(df[seqs_column_name]):
        if (seq.count('*')*100/len(seq)) <= pct: indices.append(i)
    return df.iloc[indices]

df_strid_ast = clear_asterisks(stride,'PDB_CODE')
df_strid_ast.head()
# Out:
#   PDB_CODE CHAIN_CODE  SEQ_POS AMMINO_ACID Prediction
# 0     1w0n          A       12         ILE      Other
# 1     1w0n          A       13         THR       Beta
# 2     1w0n          A       14         LYS       Beta
# 3     1w0n          A       15         VAL       Beta
# 4     1w0n          A       16         GLU       Beta

# %%
df_dssp_ast = clear_asterisks(dssp,'PDB_CODE')
df_dssp_ast.head()
# Out:
#   PDB_CODE CHAIN_CODE  SEQ_POS AMMINO_ACID Prediction
# 0     1w0n          A       12         ILE       Coil
# 1     1w0n          A       13         THR       Beta
# 2     1w0n          A       14         LYS       Beta
# 3     1w0n          A       15         VAL       Beta
# 4     1w0n          A       16         GLU       Beta

# %%
dict_a = {'H':[],'E':[],'C':[]}
# dict_f = {'C':[],'H':[],'E':[]}
# dict_p = {'C':[],'H':[],'E':[]}
# dict_s = {'C':[],'H':[],'E':[]}

for se,sst in zip(df_stride['AMMINO_ACID'],df_stride['AMMINO_ACID']):
    for s,ss in zip(se,sst):
        if s == 'A':
            if ss == 'Coil': dict_a['C'].append(1)
            elif ss == 'Helix': dict_a['H'].append(1)
            elif ss == 'Beta': dict_a['E'].append(1)
        elif s == 'F':        
            # if ss == 'Coil': dict_f['C'].append(1)
            # elif ss == 'Helix': dict_f['H'].append(1)
            # elif ss == 'beta': dict_f['E'].append(1)
            if ss == 'Coil': dict_a['C'].append(1)
            elif ss == 'Helix': dict_a['H'].append(1)
            elif ss == 'Beta': dict_a['E'].append(1)
        elif s == 'P':        
            # if ss == 'C': dict_p['C'].append(1)
            # elif ss == 'H': dict_p['H'].append(1)
            # elif ss == 'E': dict_p['E'].append(1)
            if ss == 'Coil': dict_a['C'].append(1)
            elif ss == 'Helix': dict_a['H'].append(1)
            elif ss == 'Beta': dict_a['E'].append(1)
        elif s == 'S':        
            # if ss == 'C': dict_s['C'].append(1)
            # elif ss == 'H': dict_s['H'].append(1)
            # elif ss == 'E': dict_s['E'].append(1)
            if ss == 'Coil': dict_a['C'].append(1)
            elif ss == 'Helix': dict_a['H'].append(1)
            elif ss == 'Beta': dict_a['E'].append(1)
                
                
for k in dict_a.keys(): dict_a[k] = sum(dict_a[k])
# for k in dict_f.keys(): dict_f[k] = sum(dict_f[k])
# for k in dict_p.keys(): dict_p[k] = sum(dict_p[k])
# for k in dict_s.keys(): dict_s[k] = sum(dict_s[k])
print('dict_a:  ',dict_a)
# print('dict_f:  ',dict_f)
# print('dict_p:  ',dict_p)
# print('dict_s:  ',dict_s)
# Out:
# dict_a:   {'H': 0, 'E': 0, 'C': 0}

# %%
codes = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L',
         'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

def show_matrix(m):
    #display a matrix
    cm = sns.light_palette("seagreen", as_cmap=True)
    display(m.style.background_gradient(cmap=cm))

def one_hot_encode(seq):
    o = list(set(codes) - set(seq))
    s = pd.DataFrame(list(seq))    
    x = pd.DataFrame(np.zeros((len(seq),len(o)),dtype=int),columns=o)    
    a = s[0].str.get_dummies(sep=',')
    a = a.join(x)
    a = a.sort_index(axis=1)
    show_matrix(a)
    e = a.values.flatten()
    return e

# %%
pep = ''

# %%
e=one_hot_encode(pep)
# Out:
# <style  type="text/css" >
# ...

# %%
blosum = ep.blosum62

def blosum_encode(seq):
    #encode a peptide into blosum features
    s=list(seq)
    x = pd.DataFrame([blosum[i] for i in seq]).reset_index(drop=True)
    show_matrix(x)
    e = x.values.flatten()    
    return e

def random_encode(p):
    return [np.random.randint(20) for i in pep]

e=blosum_encode(pep)
# Out:
# <style  type="text/css" >
# ...

# %%
df = ep.get_training_set()
# display(df[:5])

# %%
df.head()
# Out:
#          allele     peptide    ic50 measurement_inequality measurement_type  \
# 0  BoLA-1*21:01  AENDTLVVSV  7817.0                      =     quantitative
# 1  BoLA-1*21:01  NQFNGGCLLV  1086.0                      =     quantitative
# 2  BoLA-2*08:01   AAHCIHAEW    21.0                      =     quantitative
# 3  BoLA-2*08:01   AAKHMSNTY  1299.0                      =     quantitative
# 4  BoLA-2*08:01  DSYAYMRNGW     2.0                      =     quantitative
#
#                                measurement_source original_allele    log50k  \
# 0  Barlow - purified MHC/competitive/fluorescence    BoLA-1*02101  0.171512
# 1       Barlow - purified MHC/direct/fluorescence    BoLA-1*02101  0.353937
# 2       Barlow - purified MHC/direct/fluorescence    BoLA-2*00801  0.718615
# 3       Barlow - purified MHC/direct/fluorescence    BoLA-2*00801  0.337385
# 4       Barlow - purified MHC/direct/fluorescence    BoLA-2*00801  0.935937
#
#    length
# 0      10
# 1      10
# 2       9
# ...
